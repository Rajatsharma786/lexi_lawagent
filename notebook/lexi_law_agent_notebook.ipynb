# %%
from dotenv import load_dotenv
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain_openai import ChatOpenAI
from sentence_transformers import SentenceTransformer
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
from aiolimiter import AsyncLimiter
from langchain.schema import Document
from openai import OpenAI
from collections import deque
from langchain_community.cross_encoders import HuggingFaceCrossEncoder
from langchain.retrievers.document_compressors import CrossEncoderReranker
from langchain.retrievers.document_compressors import LLMChainFilter
from langchain.retrievers import ContextualCompressionRetriever
import time
import asyncio
import uuid
import os
load_dotenv()
# Out:
# True

# %%
laws_dir = "data/law/"       
procedures_dir = "data/procedures/"

# %%
embeddings = HuggingFaceEmbeddings(model_name="nlpaueb/legal-bert-base-uncased",model_kwargs={"device": "cuda"})
summariser = ChatOpenAI(model="gpt-4o-mini", temperature= 0,
                    max_tokens= 200,)
# summariser = ChatOpenAI(
#     model="meta-llama/Llama-3.1-8B-Instruct",
#     openai_api_base="https://mv8dkx45ioa5iuc9.us-east-1.aws.endpoints.huggingface.cloud/v1",
#     openai_api_key=os.environ["hf_token"],
#     temperature=0
# )
# Out:
# No sentence-transformers model found with name nlpaueb/legal-bert-base-uncased. Creating a new one with mean pooling.

# %%
def clean_text(text: str) -> str:
    # strip headers/footers and blank lines
    lines = [l for l in text.splitlines() if l.strip() and not l.lower().startswith('page')]
    return "\n".join(lines)

# %%
# store timestamps of last minute's requests
request_times = deque()
RPM_LIMIT = 490
WINDOW = 60   # seconds

async def rate_guard():
    now = time.time()
    # drop requests older than 60s
    while request_times and now - request_times[0] > WINDOW:
        request_times.popleft()
    if len(request_times) >= RPM_LIMIT:
        sleep_for = WINDOW - (now - request_times[0])
        print(f"RPM > {RPM_LIMIT}, sleeping {sleep_for:.0f}s")
        await asyncio.sleep(sleep_for)
        return await rate_guard()   # re-check after sleep
    # log this request
    request_times.append(now)

# %%
limiter = AsyncLimiter(3, 1) 

async def summarize_batch(chunks, batch_size=5):
    """
    Send 3 chunks at a time in a single prompt and get back structured summaries.
    """
    results = []
    # Break chunks into batches of batch_size
    for i in range(0, len(chunks), batch_size):
        batch = chunks[i:i + batch_size]
        text = "\n\n---\n\n".join([c.page_content for c in batch])
        prompt = (
            "You are a helpful assistant designed to generate high-quality supporting context for a given chunk of text"
            "from a legal law pdf. This context will help a language model (LLM) better understand the chunk"
            "when it is passed separately from the pdf. For each section separated by '---', "
            "write a concise 1-2 sentence summary numbered 1, 2, 3...\n\n"
            f"{text}"
        )

        async with limiter:  # rate-limit outbound requests
            await rate_guard() 
            resp = await summariser.ainvoke(prompt)

        # split the model's response back onto the right chunks
        lines = resp.content.strip().split("\n")
        for idx, c in enumerate(batch):
            c.metadata["uuid"] = str(uuid.uuid4())
            # crude mapping: line order to chunk order
            c.metadata["summary"] = lines[idx] if idx < len(lines) else ""
            results.append(c)
    return results

# %%
pdf_semaphore = asyncio.Semaphore(3)
async def process_pdf(pdf_path, db_name):
    async with pdf_semaphore:
        print(f"Starting {pdf_path}")
        loader = PyPDFLoader(pdf_path)
        docs = loader.load()
        docs = [Document(page_content=clean_text(d.page_content)) for d in docs]
        splitter = RecursiveCharacterTextSplitter(chunk_size=6000, chunk_overlap=500)
        chunks = splitter.split_documents(docs)
        for c in chunks:
            c.metadata["source_folder"] = os.path.basename(os.path.dirname(pdf_path))
        async with limiter:
            annotated = await summarize_batch(chunks, batch_size=3)
        print(f"Completed {pdf_path} with {len(chunks)} chunks batched.")
        return annotated

# %%
async def build_db_parallel(root_path: str, db_name: str):
    all_chunks = []
    tasks = []
    for root, _, files in os.walk(root_path):
        for file in files:
            if file.lower().endswith('.pdf'):
                pdf_path = os.path.join(root, file)
                tasks.append(process_pdf(pdf_path, db_name))
    # Run up to 3 PDFs in parallel
    results = await asyncio.gather(*tasks)
    for annotated in results:
        all_chunks.extend(annotated)

    chroma_db = Chroma.from_documents(
        all_chunks,
        embeddings,
        collection_name=db_name,
        persist_directory=f"./{db_name}_chroma",
        collection_metadata={"hnsw:space": "cosine"}
    )
    return chroma_db

# %%
async def main():
    laws_task = build_db_parallel("data/law", "laws_db")
    proc_task = build_db_parallel("data/procedures", "procedures_db")
    laws_db, procedures_db = await asyncio.gather(laws_task, proc_task)
    print("Both vector stores ready.")
    return laws_db, procedures_db

laws_db, procedures_db = await main()
# Out:
# Starting data/law\vic_acts_laws_pdfs\02-15aa013-authorised.pdf
# Starting data/law\vic_acts_laws_pdfs\03-69aa015-authorised.pdf
# Starting data/law\vic_acts_laws_pdfs\03-81aa025-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\02-15aa013-authorised.pdf with 84 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\04-107aa045-authorised.PDF
# Completed data/law\vic_acts_laws_pdfs\03-81aa025-authorised.pdf with 101 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\04-15aa022-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\03-69aa015-authorised.pdf with 118 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\04-16aa014-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\04-15aa022-authorised.pdf with 44 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\05-49aa022-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\04-16aa014-authorised.pdf with 61 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\06-15aa012%20authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\06-15aa012%20authorised.pdf with 22 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\08-46aa068-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\05-49aa022-authorised.pdf with 90 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\08-47aa027-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\04-107aa045-authorised.PDF with 208 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\09-56aa041-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\08-47aa027-authorised.pdf with 222 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\10-6aa089-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\09-56aa041-authorised.pdf with 297 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\11-47aa009-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\11-47aa009-authorised.pdf with 22 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\13-67aa051-authorised.PDF
# Completed data/law\vic_acts_laws_pdfs\08-46aa068-authorised.pdf with 413 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\14-27aa018-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\14-27aa018-authorised.pdf with 127 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\14-60aa032-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\10-6aa089-authorised.pdf with 359 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\149ab927-8d2b-3922-b10b-1d65f3eca305_88-33aa067%20authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\149ab927-8d2b-3922-b10b-1d65f3eca305_88-33aa067%20authorised.pdf with 83 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\18-25aa006%20authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\14-60aa032-authorised.pdf with 177 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\19-5aa004%20authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\19-5aa004%20authorised.pdf with 51 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\19-8aa010-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\18-25aa006%20authorised.pdf with 109 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\24-27aa002-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\19-8aa010-authorised.pdf with 85 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\4eb53a96-bf84-3b5d-a94c-4dd1d139bd8e_63-7016a001.pdf
# Completed data/law\vic_acts_laws_pdfs\4eb53a96-bf84-3b5d-a94c-4dd1d139bd8e_63-7016a001.pdf with 8 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\58-6231aa312-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\24-27aa002-authorised.pdf with 193 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\58-6246aa199-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs\58-6246aa199-authorised.pdf with 181 chunks batched.
# Starting data/law\vic_acts_laws_pdfs\66-7405aa143-authorised.pdf
# Completed data/law\vic_acts_laws_pdfs
chunks batched.
# Starting data/law\vic_Statutory_laws_pdfs\fdcd314c-c78f-37da-ad37-82227295314c_18-130sra001%20authorised.pdf
# Completed data/law\vic_Statutory_laws_pdfs\943ed6db-c9fe-3415-8891-0e4f22a1c24b_19-74sra001%20authorised.pdf with 11 chunks batched.
# Starting data/law\vic_Statutory_laws_pdfs\fe70bd43-3695-3c98-b31d-47515d96977d_16-60sra001%20authorised.pdf
# Completed data/law\vic_Statutory_laws_pdfs\fdcd314c-c78f-37da-ad37-82227295314c_18-130sra001%20authorised.pdf with 16 chunks batched.
# Starting data/law\vic_Statutory_laws_pdfs\ffee8252-91f8-3920-98c5-7e21c78a89d4_17-40sra002%20authorised.pdf
# Completed data/law\vic_Statutory_laws_pdfs\fe70bd43-3695-3c98-b31d-47515d96977d_16-60sra001%20authorised.pdf with 11 chunks batched.
# Starting data/procedures\Fedral_court\affidavitefiling_divorce_0921v2.pdf
# Completed data/procedures\Fedral_court\affidavitefiling_divorce_0921v2.pdf with 2 chunks batched.
# Starting data/procedures\Fedral_court\application_proceeding_fl_0925v1.pdf
# Completed data/procedures\Fedral_court\application_proceeding_fl_0925v1.pdf with 5 chunks batched.
# Starting data/procedures\Fedral_court\bcy_b2_application_0925v1_0.pdf
# Completed data/law\vic_Statutory_laws_pdfs\ffee8252-91f8-3920-98c5-7e21c78a89d4_17-40sra002%20authorised.pdf with 17 chunks batched.
# Starting data/procedures\Fedral_court\pdf_acknowledgement_service_divorce_0625v1.pdf
# Completed data/procedures\Fedral_court\bcy_b2_application_0925v1_0.pdf with 2 chunks batched.
# Starting data/procedures\magistrate_court\Practice Direction No. 1 of 2025_Court practice and modes of appearance_As at 21.07.2025.pdf
# Completed data/procedures\Fedral_court\pdf_acknowledgement_service_divorce_0625v1.pdf with 1 chunks batched.
# Starting data/procedures\magistrate_court\Practice Direction No. 2 of 2025_Civil Jurisdiction Practice Direction_As at 21.07.2025.pdf
# Completed data/procedures\magistrate_court\Practice Direction No. 1 of 2025_Court practice and modes of appearance_As at 21.07.2025.pdf with 15 chunks batched.
# Starting data/procedures\magistrate_court\Practice Direction No. 6 of 2022_Updated.pdf
# Completed data/procedures\magistrate_court\Practice Direction No. 2 of 2025_Civil Jurisdiction Practice Direction_As at 21.07.2025.pdf with 25 chunks batched.
# Starting data/procedures\magistrate_court\Scale of Costs - 1 January 2025.pdf
# Completed data/procedures\magistrate_court\Practice Direction No. 6 of 2022_Updated.pdf with 14 chunks batched.
# Starting data/procedures\Supreme_court\CC1CommercialCourt_FirstRevision21122017.pdf
# Completed data/procedures\magistrate_court\Scale of Costs - 1 January 2025.pdf with 11 chunks batched.
# Starting data/procedures\Supreme_court\CoA Civil - Form 64A- Submissions.pdf
# Completed data/procedures\Supreme_court\CoA Civil - Form 64A- Submissions.pdf with 1 chunks batched.
# Starting data/procedures\Supreme_court\CoA Civil - Form 64B - Application other than for leave to appeal.pdf
# Completed data/procedures\Supreme_court\CoA Civil - Form 64B - Application other than for leave to appeal.pdf with 2 chunks batched.
# Starting data/procedures\Supreme_court\CoA Civil - Form 64C - List of persons served.pdf
# Completed data/procedures\Supreme_court\CoA Civil - Form 64C - List of persons served.pdf with 2 chunks batched.
# Starting data/procedures\Supreme_court\CoA Civil - Form 64D - Notice of opposition.pdf
# Completed data/procedures\Supreme_court\CoA Civil - Form 64D - Notice of opposition.pdf with 2 chunks batched.
# Starting data/procedures\Supreme_court\CoA Civil - Form 64F - Application to set aside or vary dismissal of leave application.pdf
# Completed data/procedures\Supreme_court\CoA Civil - Form 64F - Application to set aside or vary dismissal of leave application.pdf with 2 chunks batched.
# Starting data/procedures\Supreme_court\CoA Civil - Form 64H - Notice of objection to competency.pdf
# Completed data/procedures\Supreme_court\CoA Civil - Form 64H - Notice of objection to competency.pdf with 2 chunks batched.
# Starting data/procedures\Supreme_court\Form 46A - Summons.pdf
# Completed data/procedures\Supreme_court\Form 46A - Summons.pdf with 1 chunks batched.
# Starting data/procedures\Supreme_court\Form 5A - Writ.pdf
# Completed data/procedures\Supreme_court\Form 5A - Writ.pdf with 4 chunks batched.
# Starting data/procedures\Supreme_court\Form 5B - Originating Motion.pdf
# Completed data/procedures\Supreme_court\Form 5B - Originating Motion.pdf with 4 chunks batched.
# Starting data/procedures\Supreme_court\Form 6A - Affidavit-Declaration of Service - Interlocutory Summons.pdf
# Completed data/procedures\Supreme_court\Form 6A - Affidavit-Declaration of Service - Interlocutory Summons.pdf with 2 chunks batched.
# Starting data/procedures\Supreme_court\form_8a_-_notice_of_appearance_march_2019.pdf
# Completed data/procedures\Supreme_court\form_8a_-_notice_of_appearance_march_2019.pdf with 1 chunks batched.
# Starting data/procedures\Supreme_court\gen1practicenotesandnoticetotheprofession.pdf
# Completed data/procedures\Supreme_court\gen1practicenotesandnoticetotheprofession.pdf with 3 chunks batched.
# Starting data/procedures\Supreme_court\Trial Division - Civil - affidavit.pdf
# Completed data/procedures\Supreme_court\Trial Division - Civil - affidavit.pdf with 3 chunks batched.
# Completed data/procedures\Supreme_court\CC1CommercialCourt_FirstRevision21122017.pdf with 49 chunks batched.
# Completed data/law\vic_Statutory_laws_pdfs\21-116sra009-authorised.pdf with 434 chunks batched.
# Both vector stores ready.

# %%
chatgpt = ChatOpenAI(model="gpt-4o-mini", temperature=0)
similarity_retriever = laws_db.as_retriever(search_type="similarity",
                                              search_kwargs={"k": 5})

#  LLMChainfilter decides which of the initially retrieved documents to filter out and which ones to return
# Retriever 2 - retrieves the documents similar to query and then applies the filter
_filter = LLMChainFilter.from_llm(llm=chatgpt)
compressor_retriever = ContextualCompressionRetriever(
    base_compressor=_filter, base_retriever=similarity_retriever
)

# download an open-source reranker model - BAAI/bge-reranker-v2-m3
reranker = HuggingFaceCrossEncoder(model_name="BAAI/bge-reranker-large")
reranker_compressor = CrossEncoderReranker(model=reranker, top_n=3)

# Retriever 3 - Uses a Reranker model to rerank retrieval results from the previous retriever
final_retriever = ContextualCompressionRetriever(
    base_compressor=reranker_compressor, base_retriever=compressor_retriever
)

# %%
query = "What is the purpose of the Building and Construction Industry Security of Payment Act 2002?"
top_docs = final_retriever.invoke(query)

# %%
top_docs
# Out:
# [Document(metadata={'uuid': '9913ce61-2e56-415a-a6e6-e56a444261ca', 'summary': '2. The objective of these regulations is to establish forms necessary for the implementation of the Building and Construction Industry Security of Payment Act 2002.', 'source_folder': 'vic_Statutory_laws_pdfs'}, page_content='Authorised by the Chief Parliamentary Counsel \n1   \nAuthorised Version No. 001 \nBuilding and Construction Industry Security \nof Payment Regulations 2023 \nS.R. No. 34/2023 \nAuthorised Version as at \n27 May 2023 \n 1 Objective \nThe objective of these Regulations is to prescribe \nforms for the purposes of the Building and \nConstruction Industry Security of Payment \nAct 2002. \n 2 Authorising provision \nThese Regulations are made under section 52 of \nthe Building and Construction Industry \nSecurity of Payment Act 2002. \n 3 Commencement \nThese Regulations come into operation on 27 May \n2023. \n 4 Revocation \nThe Building and Construction Industry Security \nof Payment Regulations 2013\n1 are revoked. \n 5 Definition \nIn these Regulations, the Act means the Building \nand Construction Industry Security of \nPayment Act 2002. \n 6 Notice of intention to exercise lien \nFor the purposes of section 12A of the Act, the \nprescribed form of a notice of intention to exercise \na lien is Form 1 in Schedule 1.'),
#  Document(metadata={'uuid': '27790b5a-6e49-4c83-8403-2d3b1b954196', 'source_folder': 'vic_acts_laws_pdfs', 'summary': ''}, page_content='Authorised by the Chief Parliamentary Counsel \nPart 4—Miscellaneous \nBuilding and Construction Industry Security of Payment Act 2002 \nNo. 15 of 2002 \n76   \nunder a construction contract entered into before \nthe commencement of section 42 of the 2006 Act \nand any such payment claim is to be dealt with in \naccordance with this Act as if the 2006 Act had \nnot been enacted. \n * * * * * \n ═══════════════  \nS. 54 \nrepealed by \nNo. 42/2006 \ns. 43.'),
#  Document(metadata={'summary': '2. The objectives of the Regulations include defining the contract price for major domestic building contracts, specifying exempt work and persons, allowing cost-plus contracts, and detailing procedures for progress payments and dispute resolution fees. ', 'source_folder': 'vic_Statutory_laws_pdfs', 'uuid': '455b23e7-da7b-4823-9c83-ce78cdc3e693'}, page_content='Authorised by the Chief Parliamentary Counsel \n1   \nAuthorised Version No. 004 \nDomestic Building Contracts \nRegulations 2017 \nS.R. No. 18/2017 \nAuthorised Version incorporating amendments as at \n1 July 2021 \n 1 Objectives \nThe objectives of these Regulations are—  \n (a) to fix the amount of the contract price for \nthe carrying out of domestic building work \nfor the purposes of the definition of major \ndomestic building contract in section 3(1) \nof the Act; and \n (b) to prescribe certain work as building work to \nwhich the Act does not apply; and \n (c) to exempt certain persons and contracts from \nvarious provisions of the Act; and \n (d) to allow certain contracts to be cost plus \ncontracts for the purposes of section 13 of \nthe Act; and \n (e) to prescribe, with regard to progress \npayments, the manner in which parties to a \ncontract may agree that section 40(2) and (3) \nof the Act do not apply; and \n (f) to prescribe a fee for requests to the chief \ndispute resolution officer for an assessor \nunder section 48C(3) of the Act. \n 2 Authorising provision \nThese Regulations are made under section 135 of \nthe Domestic Building Contracts Act 1995.')]
